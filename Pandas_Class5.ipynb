# %% [markdown]
# <a href="https://colab.research.google.com/github/gupteshmahale04-arch/Pandas/blob/main/Pandas_Class5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as  pd
data = {
    "Product": ['Pen', 'Notebook', 'Pencil', 'Marker', 'Eraser'],
    'Price': [10,50,5,30,8],
    'Stock': [100,60,200,80,150],
    'Rating': [4.5,4.7,4.2,4.8,4.3]
}

df = pd.DataFrame(data)

#1. short by a single column -> Price, ascending.
print(df.sort_values(by='Price'))

#2.sort by a single column -> Rating, descending.
print(df.sort_values(by='Rating',ascending=False))

#3. sort by multiple columns -> Price and Stocks
df.sort_values(by=['Price','Stock'])

#4. sort index -> in descending order.
df.sort_index(ascending=False)
# Out:
#     Product  Price  Stock  Rating
# 2    Pencil      5    200     4.2
# 4    Eraser      8    150     4.3
# 0       Pen     10    100     4.5
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
#     Product  Price  Stock  Rating
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5
# 4    Eraser      8    150     4.3
# 2    Pencil      5    200     4.2
#     Product  Price  Stock  Rating
# 4    Eraser      8    150     4.3
# 3    Marker     30     80     4.8
# 2    Pencil      5    200     4.2
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
#1.Mean of numeric coiumns only
df.mean(numeric_only=True)

#2.Medain of numeric coiumns only
df.median(numeric_only=True)

#3.Mode of numeric coiumns only
df.mode(numeric_only=True)

#4.Standard Deviation
df.std(numeric_only=True)

#5.Complele Statis Summary of stats
df.describe()
# Out:
#            Price       Stock    Rating
# count   5.000000    5.000000  5.000000
# mean   20.600000  118.000000  4.500000
# std    19.152023   56.745044  0.254951
# min     5.000000   60.000000  4.200000
# 25%     8.000000   80.000000  4.300000
# 50%    10.000000  100.000000  4.500000
# 75%    30.000000  150.000000  4.700000
# max    50.000000  200.000000  4.800000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
# 1. caunt how meny times each product appears
print(df['Price'].value_counts())
# 2. Show percentage instead of counts.
print(df['Product'].value_counts(normalize=True))
# 3.Count values for column rating
print(df['Rating'].value_counts())
# Out:
# Price
# 10    1
# 50    1
# 5     1
# 30    1
# 8     1
# Name: count, dtype: int64
# Product
# Pen         0.2
# Notebook    0.2
# Pencil      0.2
# Marker      0.2
# Eraser      0.2
# Name: proportion, dtype: float64
# Rating
# 4.5    1
# 4.7    1
# 4.2    1
# 4.8    1
# 4.3    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
#1.Correlation between all numeric column .
print(df.corr(numeric_only=True))

#-ve correlation -> One increases 2nd decresaes
#+ve correlation -> one increases other increases

#2.Covariance between all numeric column .
print(df.cov(numeric_only=True))

#3.Correlation between 2 specific column .
print(df['Price'].corr(df['Stock']))
# Out:
#            Price     Stock    Rating
# Price   1.000000 -0.817551  0.814078
# Stock  -0.817551  1.000000 -0.933145
# Rating  0.814078 -0.933145  1.000000
#           Price   Stock  Rating
# Price   366.800  -888.5   3.975
# Stock  -888.500  3220.0 -13.500
# Rating    3.975   -13.5   0.065
# -0.8175509599153405

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height
import pandas as pd
d={
    "Name":["Rohan","Ram","Raju","Roky","Ravee"],
    "Age":[16,21,15,19,23],
    "Score":[19,25,36,15,24],
    "Hight":[5.9,4.11,5.7,5.11,5.4]

}

df=pd.DataFrame(d)
print(df)



# 2. Sort the data by Score (descending)
# Write your code here
print(df.sort_values(by='Score',ascending=False))

# 3. Get mean, median, mode, and std of numeric columns
# Write your code here
print(df.mean(numeric_only=True))
print(df.median(numeric_only=True))
print(df.mode(numeric_only=True))
print(df.std(numeric_only=True))

# 4. Use value_counts on Name or any categorical column
# Write your code here
print(df['Name'].value_counts())

# 5. Compute corr() and cov() for all numeric columns
# Write your code here
print(df.corr(numeric_only=True))
print(df.cov(numeric_only=True))
# Out:
#     Name  Age  Score  Hight
# 0  Rohan   16     19   5.90
# 1    Ram   21     25   4.11
# 2   Raju   15     36   5.70
# 3   Roky   19     15   5.11
# 4  Ravee   23     24   5.40
#     Name  Age  Score  Hight
# 2   Raju   15     36   5.70
# 1    Ram   21     25   4.11
# 4  Ravee   23     24   5.40
# 0  Rohan   16     19   5.90
# 3   Roky   19     15   5.11
# Age      18.800
# Score    23.800
# Hight     5.244
# dtype: float64
# Age      19.0
# Score    24.0
# Hight     5.4
# dtype: float64
#    Age  Score  Hight
# 0   15     15   4.11
# 1   16     19   5.11
# 2   19     24   5.40
# 3   21     25   5.70
# 4   23     36   5.90
# Age      3.346640
# Score    7.918333
# Hight    0.701163
# dtype: float64
# Name
# Rohan    1
# Ram      1
# Raju     1
# Roky     1
# Ravee    1
# Name: count, dtype: int64
#             Age     Score     Hight
# Age    1.000000 -0.294342 -0.579150
# Score -0.294342  1.000000  0.101944
# Hight -0.579150  0.101944  1.000000
#           Age   Score    Hight
# Age    11.200  -7.800 -1.35900
# Score  -7.800  62.700  0.56600
# Hight  -1.359   0.566  0.49163

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
