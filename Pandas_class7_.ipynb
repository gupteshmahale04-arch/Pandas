# %% [markdown]
# <a href="https://colab.research.google.com/github/gupteshmahale04-arch/Pandas/blob/main/Pandas_class7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 7: Merging, Joining & Concatenation
# Welcome to **Class 7** of our Pandas series. Today we’ll learn how to combine multiple DataFrames using different techniques.

# %% [markdown]
# ## 1. Using `concat()` for Stacking Data
# - `pd.concat()` combines DataFrames vertically (rows) or horizontally (columns).
# - Use `axis=0` for vertical stacking (default), `axis=1` for horizontal.
# - `ignore_index=True` can reset the index after concatenation.

# %%
import pandas as pd
# Dataset 1: Product details
df1 = pd.DataFrame({
    'ProductID' : [101,102,103],
    'ProductName': ['Pen', 'Notebook', 'Marker'],
    'Price': [10,50,30]
})

# Dataset 2: More products (same columns as df1 → good for vertical stacking)
df2 = pd.DataFrame({
    'ProductID': [104, 105],
    'ProductName': ['Pencil', 'Eraser'],
    'Price': [5,4]
})
# Dataset 3: Additional info (different columns → good for horizontal stacking)
df3 = pd.DataFrame({
    'Stock': [100, 60, 80,65,52],
    'Rating': [4.5,4.7,4.8,9.9,8.0]
})


print(f'DF1 {df1}')
print(f'DF2 {df2}')
print(f'DF3 {df3}')



#1. Vertical Stacking -> By Defauklt (axis=0)
vertical_stacking = pd.concat([df1, df2], ignore_index=True)
print(vertical_stacking)

#2. Horizontal Stacking (axis=1)
horizontal_stacking = pd.concat([df1, df3], axis=1)
horizontal_stacking
# Out:
# DF1    ProductID ProductName  Price
# 0        101         Pen     10
# 1        102    Notebook     50
# 2        103      Marker     30
# DF2    ProductID ProductName  Price
# 0        104      Pencil      5
# 1        105      Eraser      4
# DF3    Stock  Rating
# 0    100     4.5
# 1     60     4.7
# 2     80     4.8
# 3     65     9.9
# 4     52     8.0
#    ProductID ProductName  Price
# 0        101         Pen     10
# 1        102    Notebook     50
# 2        103      Marker     30
# 3        104      Pencil      5
# 4        105      Eraser      4
#    ProductID ProductName  Price  Stock  Rating
# 0      101.0         Pen   10.0    100     4.5
# 1      102.0    Notebook   50.0     60     4.7
# 2      103.0      Marker   30.0     80     4.8
# 3        NaN         NaN    NaN     65     9.9
# 4        NaN         NaN    NaN     52     8.0

# %% [markdown]
# ## 2. Using `merge()` for SQL-Style Joins
# - `merge()` is similar to SQL joins.
# - Specify `on` or `left_on`/`right_on` to choose key columns.
# - Join types: `inner` (default), `left`, `right`, `outer`.

# %%
#You guys have to concat df1 and df2 row wise.
product = pd.concat([df1, df2],ignore_index=True)

sales = pd.DataFrame({
    'ProductID':[101,102,104,106],
    'UnitsSold':[500,200,150,50]
})
print(product)
print(sales)


#1. Inner join (Dono dataframes ke beech only matching ProductId)
#                 left   right
inner = pd.merge(product,sales,how="inner")

#2. Left join
left = pd.merge(product,sales,how="left")

#3. Right join
right = pd.merge(product,sales,how="right")

#4. Outer join (Everything, even unmatched)
outer = pd.merge(product,sales,how="outer")

outer
# Out:
#    ProductID ProductName  Price
# 0        101         Pen     10
# 1        102    Notebook     50
# 2        103      Marker     30
# 3        104      Pencil      5
# 4        105      Eraser      4
#    ProductID  UnitsSold
# 0        101        500
# 1        102        200
# 2        104        150
# 3        106         50
#    ProductID ProductName  Price  UnitsSold
# 0        101         Pen   10.0      500.0
# 1        102    Notebook   50.0      200.0
# 2        103      Marker   30.0        NaN
# 3        104      Pencil    5.0      150.0
# 4        105      Eraser    4.0        NaN
# 5        106         NaN    NaN       50.0

# %% [markdown]
# ## 3. Using `join()` with Index Alignment
# - `join()` joins DataFrames on their index or on a key column.
# - By default, joins on index; can specify `on='col'`.
# - Useful for adding columns to an existing DataFrame.

# %%
sales = pd.DataFrame({
    'UnitsSold':[500,200,150,50,350]
}, index=[101,102,103,104,105])
print(product)
print(sales)

#1. Join stock info to products.
p_indexed = product.set_index('ProductID')
joined = p_indexed.join(sales)
joined
# Out:
#    ProductID ProductName  Price
# 0        101         Pen     10
# 1        102    Notebook     50
# 2        103      Marker     30
# 3        104      Pencil      5
# 4        105      Eraser      4
#      UnitsSold
# 101        500
# 102        200
# 103        150
# 104         50
# 105        350
#           ProductName  Price  UnitsSold
# ProductID
# 101               Pen     10        500
# 102          Notebook     50        200
# 103            Marker     30        150
# 104            Pencil      5         50
# 105            Eraser      4        350

# %% [markdown]
# ## 4. Practical Examples
# - Combine sales and revenue data to see performance.
# - Merge students with marks to link records.
# - Practice with realistic datasets to understand alignment and missing data handling.

# %%
from numpy._core.defchararray import index
import pandas as pd
Sales=pd.DataFrame({
    'ProductID':[101,102,104,106],
    'UnitsSold':[500,200,150,50]

                })
Revenue=pd.DataFrame({
    'ProductID':[101,102,104,106],
    'Revenue':["5L","9L","6.5L","9.5L"]

})
pd.concat([Sales,Revenue],ignore_index=True)
pd.concat([Sales,Revenue],axis=1)

Student=pd.DataFrame({
   " S_Name":["Guptesh","Roy","Jaya"],
   "Marks":[10,9,8]

})
Records=pd.DataFrame({
    "Class":["10th","12th","9th"],
    "Roll_No" :[15,18,52]
})

pd.concat([Student,Records],axis=1)
pd.concat([Student,Records],ignore_index=True)
# Out:
#     S_Name  Marks Class  Roll_No
# 0  Guptesh   10.0   NaN      NaN
# 1      Roy    9.0   NaN      NaN
# 2     Jaya    8.0   NaN      NaN
# 3      NaN    NaN  10th     15.0
# 4      NaN    NaN  12th     18.0
# 5      NaN    NaN   9th     52.0

# %% [markdown]
# ## Mini Practice
# 1. Create three DataFrames: Products, Sales, and Revenue.
# 2. Concatenate them vertically and horizontally.
# 3. Merge Sales and Revenue using different join types.
# 4. Join Products with Sales based on index or a key.
# 5. Analyze missing values after joins.

# %%
# 1. Create three DataFrames: Products, Sales, and Revenue.
import pandas as pd
Products=pd.DataFrame({
    "ProductID":[101,102,103,104,105],
    "ProductName":["Pen","Notebook","Marker","Pencil","Eraser"],
    "Price":[10,50,30,5,4]
})
Sales=pd.DataFrame({
    'ProductID':[101,102,104,106],
    'UnitsSold':[500,200,150,50]

                })
Revenue=pd.DataFrame({
    'ProductID':[101,102,104,106],
    'Revenue':["5L","9L","6.5L","9.5L"]

})

# 2. Concatenate them vertically and horizontally
# Write your code here
pd.concat([Products,Sales],ignore_index=True)
pd.concat([Products,Sales],axis=1)

# 3. Merge Sales and Revenue using different join types (inner, left, right, outer)
# Write your code here

pd.merge(Sales,Revenue,how="inner")
pd.merge(Sales,Revenue,how="left")
pd.merge(Sales,Revenue,how="right")
pd.merge(Sales,Revenue,how="outer")

# pd.concat([Sales,Revenue],)
# 4. Join Products with Sales based on index or a key
# Write your code here
p_indexed = Products.set_index('ProductID')
joined = p_indexed.join(Sales)
joined

# 5. Analyze missing values after joins
# Use isna(), info(), or describe() to explore gaps
# Write your code here
joined.isna()
joined.info()
joined.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 101 to 105
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductName  5 non-null      object
#  1   Price        5 non-null      int64
#  2   ProductID    0 non-null      float64
#  3   UnitsSold    0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 200.0+ bytes
#            Price  ProductID  UnitsSold
# count   5.000000        0.0        0.0
# mean   19.800000        NaN        NaN
# std    19.879638        NaN        NaN
# min     4.000000        NaN        NaN
# 25%     5.000000        NaN        NaN
# 50%    10.000000        NaN        NaN
# 75%    30.000000        NaN        NaN
# max    50.000000        NaN        NaN

# %% [markdown]
# ---
# ## Summary
# - Used `concat()` for stacking data vertically and horizontally.
# - Performed SQL-style joins with `merge()`.
# - Applied `join()` with index alignment.
# - Explored practical use-cases like sales vs revenue, students vs marks.
