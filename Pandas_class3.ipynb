# %% [markdown]
# <a href="https://colab.research.google.com/github/gupteshmahale04-arch/Pandas/blob/main/Pandas_class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 3: Data Cleaning Essentials
# Welcome to **Class 3** of our Pandas series. Today we’ll learn how to clean and prepare data for analysis.

# %% [markdown]
# ## Handling Missing Values
# Real-world datasets often have missing data. Pandas offers:
# - `isna()` / `isnull()` → detect missing values (returns True/False)
# - `dropna()` → remove missing values (rows/columns)
# - `fillna()` → replace missing values with a given value or method (e.g., forward fill)
#
# Always inspect how much data is missing before deciding to drop or fill.

# %%
import pandas as pd
import numpy as np
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, None, 35, 40, None],
    "City": ["Delhi", "Mumbai", None, "Bangalore", "Chennai"],
    "Score": [85, 91, np.nan, 88, 95]
}

b = pd.DataFrame(a)
print(b)

# 1. .isna()->null value -> marks by true
print(b.isna())

# 2. .isnull() -> null value -> marks by true
print(b.isnull)

# .innull().sum()-> caunt null value in DS , by -column
print(b.isnull().sum())

# .dropna() -> Remove all the null value columns
print(b.dropna())

# Filling null value of Any column
b['Age'].fillna(b['Age'].mean(), inplace=True)

# Filling null value of Any column
b['Score'].fillna(0,inplace=True)

#Filling by placeholder("unknown")
b['City'].fillna("unknow",inplace=True)

print(b)
# Out:
#       Name   Age       City  Score
# 0    Alice  25.0      Delhi   85.0
# 1      Bob   NaN     Mumbai   91.0
# 2  Charlie  35.0       None    NaN
# 3    David  40.0  Bangalore   88.0
# 4     Emma   NaN    Chennai   95.0
#     Name    Age   City  Score
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False
# <bound method DataFrame.isnull of       Name   Age       City  Score
# 0    Alice  25.0      Delhi   85.0
# 1      Bob   NaN     Mumbai   91.0
# 2  Charlie  35.0       None    NaN
# 3    David  40.0  Bangalore   88.0
# 4     Emma   NaN    Chennai   95.0>
# Name     0
# Age      2
# City     1
# Score    1
# dtype: int64
#     Name   Age       City  Score
# 0  Alice  25.0      Delhi   85.0
# 3  David  40.0  Bangalore   88.0
#       Name        Age       City  Score
# 0    Alice  25.000000      Delhi   85.0
# 1      Bob  33.333333     Mumbai   91.0
# 2  Charlie  35.000000     unknow    0.0
# 3    David  40.000000  Bangalore   88.0
# 4     Emma  33.333333    Chennai   95.0
# /tmp/ipykernel_1026/3544399802.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Age'].fillna(b['Age'].mean(), inplace=True)
# /tmp/ipykernel_1026/3544399802.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Score'].fillna(0,inplace=True)
# /tmp/ipykernel_1026/3544399802.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['City'].fillna("unknow",inplace=True)

# %% [markdown]
# ## Changing Data Types (`astype`)
# - Convert a column to a different type using `astype()`.
# - Examples: converting strings to numbers, integers to floats, or columns to category.
#
# Be careful: make sure the data is compatible with the new type!

# %%
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)

d=b['Age'].astype(float)
print(d)
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    40.0
# 4    22.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Replacing Values (`replace`)
# - Use `replace()` to substitute specific values or patterns.
# - Useful for cleaning labels, fixing typos, or mapping categories.

# %%
print(b)
# chang a spesfic position
b['Name'].replace("Alice","suyog",inplace=True)


print(b)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Name  Age  Score
# 0    suyog   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# /tmp/ipykernel_1026/850307921.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Name'].replace("Alice","suyog",inplace=True)

# %% [markdown]
# ## Dropping Rows & Columns (`drop`)
# - `drop(labels, axis=0)` → drop rows by index labels.
# - `drop(labels, axis=1)` → drop columns by name.
# - Use `inplace=True` if you want to modify the DataFrame directly.

# %%
print(b)

# Rmove row
b.drop(index=2,axis=0,inplace=True)
# Remove column
b.drop(columns="Score",axis=1,inplace=True)
print(b )
# Out:
#       Name  Age  Score
# 0    suyog   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#     Name  Age
# 0  suyog   25
# 1    Bob   30
# 3  David   40
# 4   Emma   22

# %% [markdown]
# ## Detecting & Removing Duplicates
# - `duplicated()` → returns a Boolean Series marking duplicate rows.
# - `drop_duplicates()` → remove duplicate rows.
# - You can specify `subset` (columns) and `keep` ('first', 'last', or False).

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "David"],
    "Age": [25, 30, 35, 25, 30, 40],
    "Score": [88, 92, 79, 88, 92, 85]
}

df = pd.DataFrame(data)

print(df)
df.drop_duplicates().sum()#Total Duplicte value count

df.drop_duplicates(inplace=True)# agr koi duplicai ate hi to remove it
print(df)

df.drop_duplicates(subset="Name",keep='first',inplace=True)#
print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    Alice   25     88
# 4      Bob   30     92
# 5    David   40     85
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 5    David   40     85
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 5    David   40     85

# %% [markdown]
# ## Mini Practice
# 1. Create a messy DataFrame with missing values, wrong data types, typos, extra columns, and duplicates.
# 2. Clean it step-by-step using what you learned:
#    - Handle missing values
#    - Change data types
#    - Replace incorrect values
#    - Drop unnecessary rows/columns
#    - Remove duplicates

# %%
import pandas as pd
import numpy as np

# 1. Original messy DataFrame
data = {
    "Name": ["Alice", "Bob", "Chrlie", "David", "Alice", None],
    "Age": ["25", "30", None, "40", "25", "30"],
    "City": ["Delhi", "Mumbai", "Pun", "Bangalore", "Delhi", "Mumbai"],
    "Score": [85, None, 78, 88, 85, 91],
    "Extra": ["x", "y", "z", "x", "y", "z"]
}

df = pd.DataFrame(data)
print("Original messy DataFrame:")
print(df)

# 2. Handle missing values
df["Age"] = df["Age"].fillna(df["Age"].mode()[0])   # fill missing Age with mode
df["Score"] = df["Score"].fillna(df["Score"].mean()) # fill missing Score with mean
df["Name"] = df["Name"].fillna("Unknown")            # fill missing Name with 'Unknown'

# 3. Change data types
df["Age"] = df["Age"].astype(int)
df["Score"] = df["Score"].astype(float)

# 4. Replace incorrect values
df["City"] = df["City"].replace("Pun", "Pune")
df["Name"] = df["Name"].replace("Chrlie", "Charlie")

# 5. Drop unnecessary rows/columns
df = df.drop(columns=["Extra"])

# 6. Remove duplicates
df = df.drop_duplicates()

# 7. Final clean DataFrame
print("\nCleaned DataFrame:")
print(df)
print("\nDataFrame Info:")
print(df.info())
# Out:
# Original messy DataFrame:
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    NaN     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y
# 5    None    30     Mumbai   91.0     z
#
# Cleaned DataFrame:
#       Name  Age       City  Score
# 0    Alice   25      Delhi   85.0
# 1      Bob   30     Mumbai   85.4
# 2  Charlie   25       Pune   78.0
# 3    David   40  Bangalore   88.0
# 5  Unknown   30     Mumbai   91.0
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Score   5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 200.0+ bytes
# None

# %% [markdown]
# ---
# ## Summary
# - Learned to handle missing values (`isna`, `dropna`, `fillna`).
# - Converted column data types with `astype`.
# - Cleaned up incorrect entries with `replace`.
# - Removed unwanted rows/columns with `drop`.
# - Detected and removed duplicates.
