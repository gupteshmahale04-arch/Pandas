# %% [markdown]
# <a href="https://colab.research.google.com/github/gupteshmahale04-arch/Pandas/blob/main/Pandas_Class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 2: DataFrame Basics
# Welcome to **Class 2**. Today we’ll learn how to **inspect**, **select**, and **organize** data inside a DataFrame.

# %% [markdown]
# ## 1 Inspecting Data
# Quick ways to understand your dataset:
# - `head(n)` → first *n* rows (default 5)
# - `tail(n)` → last *n* rows
# - `info()` → columns, non-null counts, and dtypes
# - `shape` → (rows, columns)
# - `dtypes` → data type of each column

# %%
import pandas as pd

# Create a small DataFrame
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)
print(b)
#1 .hade(n) -> by default gives you starting 5 rows .
print(b.head())


#2 .tail ->V by default gives you ending 5 rows
print(b.tail(2))

#3 .info() ->give the informetion of DF
print(b.info())

#4. shape -> give the value of shape( row and columns)
print(b.shape)

#5 .dtypes -> give the data type of each columns
print(b.dtypes)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#     Name  Age  Score
# 3  David   40     85
# 4   Emma   22     95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Score   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None
# (5, 3)
# Name     object
# Age       int64
# Score     int64
# dtype: object

# %% [markdown]
# ## 2 Selecting Columns & Rows
# Ways to access parts of a DataFrame:
# - Single column → `df['col']`
# - Multiple columns → `df[['col1','col2']]`
# - Label-based selection → `df.loc[row_label, col_label]`
# - Integer-index selection → `df.iloc[row_idx, col_idx]`
# Tip: `:` means "all rows/columns" in that dimension.

# %%
print(b)
#Access singul columns
print(b['Age'])

#Access Multipal columns
print(b[['Age',"Score"]])

#select only row index 2 and column Score
print(b.loc[2,"Score"])

print(b.loc[2,["Age","Score"]])

#Select using indexing we use .iloc[start:stop:step]
print(b.iloc[0:4,0:2])
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# Name: Age, dtype: int64
#    Age  Score
# 0   25     88
# 1   30     92
# 2   35     79
# 3   40     85
# 4   22     95
# 79
# Age      35
# Score    79
# Name: 2, dtype: object
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %% [markdown]
# ## 3 Index & Columns Overview
# - `df.index` → row labels
# - `df.columns` → column names
# - `df.values` → underlying NumPy array (read-only; prefer using DataFrame ops)

# %%
#1 .index
print(b.index)#row is started from ,row is stop  from


#2 .columns
print(b.columns)#name of  columns

#3 .values
print(b.values) #DataFrame convert into matrix
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['Name', 'Age', 'Score'], dtype='object')
# [['Alice' 25 88]
#  ['Bob' 30 92]
#  ['Charlie' 35 79]
#  ['David' 40 85]
#  ['Emma' 22 95]]

# %% [markdown]
# ## 4 Renaming Columns & Setting an Index
# - Rename columns → `df.rename(columns={'old':'new'}, inplace=False)`
# - Set a column as index → `df.set_index('column_name', inplace=False)`
# - Reset index → `df.reset_index(inplace=False)`
#  If you don't use `inplace=True`, remember to assign the result back to a variable.

# %%
#1 .rename (column={old_name:New_name})
#inplace -> chang Original of DF
b.rename(columns={"Score":"Marks"},inplace=True)
print(b)

#2 .set_index
# set index of any column of FD
c=b.set_index("Name",inplace=True)
print(c)
print(b)

#3 .reset_index
#reset FD
b.reset_index(inplace=True)
print(b)
# Out:
#       Name  Age  Marks
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# None
#          Age  Marks
# Name
# Alice     25     88
# Bob       30     92
# Charlie   35     79
# David     40     85
# Emma      22     95
#       Name  Age  Marks
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %% [markdown]
# ## 5 Basic Attributes Recap
# - `df.columns` → names of all columns
# - `df.index` → row labels
# - `df.values` → NumPy array (data only)
# These are handy for quick checks and loops (though vectorized ops are preferred).

# %%
b.columns
b.index
b.values
# Out:
# array([['Alice', 25, 88],
#        ['Bob', 30, 92],
#        ['Charlie', 35, 79],
#        ['David', 40, 85],
#        ['Emma', 22, 95]], dtype=object)

# %% [markdown]
# ## Mini Practice
# 1. Create a DataFrame with at least 5 rows and 4 columns (mix of numeric + text).
# 2. Show the first 3 rows, last 2 rows, and the info.
# 3. Select a sub-DataFrame with only 2 columns.
# 4. Rename one column and set any column as index, then reset it back.
# 5. Print `df.shape`, `df.dtypes`, and `df.columns`.

# %%
import pandas as pd

# Create a DataFrame with at least 5 rows & 4 columns (mix of numbers + text)
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "City": ["Delhi", "Mumbai", "Pune", "Bangalore", "Chennai"],
    "Score": [85, 91, 78, 88, 95]
}

df = pd.DataFrame(data)

# Show the first 3 rows, last 2 rows, and info
# your code here
print(df.head(3))
print(df.tail(2))

# Select a sub-DataFrame with only 2 columns
# your code here
print(df["Name" ],df["City"])

# Rename one column and set any column as index, then reset it back
# your code here
df.rename(columns={"Score":"Marks"},inplace=True)
print(df)
df.set_index("Name",inplace=True)
print(df)
df.reset_index(inplace=True)
print(df)

# Print df.shape, df.dtypes, and df.columns
# your code here
print(df.shape)
print(df.dtypes)
print(df.columns)
# Out:
#       Name  Age    City  Score
# 0    Alice   25   Delhi     85
# 1      Bob   30  Mumbai     91
# 2  Charlie   35    Pune     78
#     Name  Age       City  Score
# 3  David   40  Bangalore     88
# 4   Emma   22    Chennai     95
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4       Emma
# Name: Name, dtype: object 0        Delhi
# 1       Mumbai
# 2         Pune
# 3    Bangalore
# 4      Chennai
# Name: City, dtype: object
#       Name  Age       City  Marks
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# 2  Charlie   35       Pune     78
# 3    David   40  Bangalore     88
# 4     Emma   22    Chennai     95
#          Age       City  Marks
# Name
# Alice     25      Delhi     85
# Bob       30     Mumbai     91
# Charlie   35       Pune     78
# David     40  Bangalore     88
# Emma      22    Chennai     95
#       Name  Age       City  Marks
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# ...

# %% [markdown]
# ---
# ## ✅ Summary
# - You learned to **inspect** a DataFrame (`head`, `tail`, `info`, `shape`, `dtypes`).
# - You practiced **selecting** columns/rows using `[]`, `.loc`, and `.iloc`.
# - You explored **index/columns** and basic attributes.
# - You **renamed** columns and **set/reset** an index.
#
# Next up: **Data Cleaning Essentials** (missing values, types, duplicates).
